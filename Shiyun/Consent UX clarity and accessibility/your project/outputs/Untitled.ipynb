# %%
# !python3 score_responses_v2.py
# Out:
# Scoring: P1_gpt4o_gen1 ... ✅ Success
# Scoring: P1_ollama_gen1 ... ✅ Success
# Scoring: P1_gpt4o_gen2 ... ✅ Success
# Scoring: P1_ollama_gen2 ... ✅ Success
# Scoring: P1_gpt4o_gen3 ... ⚠️ Error: GPT-4o fails to grade: Expecting value: line 1 column 1 (char 0)
# Scoring: P1_ollama_gen3 ... ✅ Success
# Scoring: P2_gpt4o_gen1 ... ✅ Success
# Scoring: P2_ollama_gen1 ... ✅ Success
# Scoring: P2_gpt4o_gen2 ... ✅ Success
# Scoring: P2_ollama_gen2 ... ✅ Success
# Scoring: P2_gpt4o_gen3 ... ✅ Success
# Scoring: P2_ollama_gen3 ... ✅ Success
# Scoring: P3_gpt4o_gen1 ... ✅ Success
# Scoring: P3_ollama_gen1 ... ✅ Success
# Scoring: P3_gpt4o_gen2 ... ✅ Success
# Scoring: P3_ollama_gen2 ... ✅ Success
# Scoring: P3_gpt4o_gen3 ... ✅ Success
# Scoring: P3_ollama_gen3 ... ✅ Success
# Scoring: P4_gpt4o_gen1 ... ✅ Success
# Scoring: P4_ollama_gen1 ... ✅ Success
# Scoring: P4_gpt4o_gen2 ... ✅ Success
# Scoring: P4_ollama_gen2 ... ✅ Success
# Scoring: P4_gpt4o_gen3 ... ✅ Success
# ...
